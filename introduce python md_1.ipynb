# %% [markdown]
# What is an Interpreter?
# Python is an interpreted language, meaning your code is executed line by line.
# Your First Python Program
# Traditionally, every programmer starts with Hello World.

# %%
print("hello world")
print("Rafi Ahmed Rizvee")
# Out:
# hello world
# Rafi Ahmed Rizvee

# %%
#testing python
name = "Rafi Ahmed Rizvee"
print(f"Welcome to {name} in python ")

# adding number 
print(100+120)
# Out:
# Welcome to Rafi Ahmed Rizvee in python
# 220

# %% [markdown]
# The print() function displays output on the screen.
#
# What can it print?
# Text (strings)
# Numbers
# Results of expressions

# %%
# This is single line comment

'''
this is multi-line comment 
'''
# Out:
# '\nthis is multi-line comment \n'

# %%
var = "Welcome to the python"

print(type(var))
print(type(2025))
print(type(2025.011))

# type -> which data type
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
def func(name1):
  print(name1)

print("Hello")
# Out:
# Hello

# %% [markdown]
# What is Mutable in Python? 🧠
# Mutable means:
# 👉 You can change the value of an object after it is created, without creating a new object.
#
# Simple Definition (Beginner Friendly)
# If a data type is mutable, you can:
#
# Modify it
#
# Add items to it
#
# Remove items from it
#
# If it is immutable, you cannot change it once it’s created.
#
# 🔁 Mutable vs Immutable (Quick Idea)
# Think of it like this:
#
# Mutable → ✏️ You can edit it
#
# Immutable → 🔒 Read-only, no editing

# %%
# list is mutable that mean this value are changeable

list = ["Rafi",25,"Dhanmondi"]

print(list)

list[0]="Rafi Ahmed Rizvee"
list[1]=26
print(list)
list.append("He is a Mern Stack Web Developer")
print(list)
list.append( 1 )
print(list)

list.remove(1)
print(list)
# Out:
# ['Rafi', 25, 'Dhanmondi']
# ['Rafi Ahmed Rizvee', 26, 'Dhanmondi']
# ['Rafi Ahmed Rizvee', 26, 'Dhanmondi', 'He is a Mern Stack Web Developer']
# ['Rafi Ahmed Rizvee', 26, 'Dhanmondi', 'He is a Mern Stack Web Developer', 1]
# ['Rafi Ahmed Rizvee', 26, 'Dhanmondi', 'He is a Mern Stack Web Developer']

# %%
l = ["Rafi",210159,'CSE']
first = l[0]
last = l[-1]
mid=l[1]
print(l)
print(first)
print(mid)
print(last)
# Out:
# ['Rafi', 210159, 'CSE']
# Rafi
# 210159
# CSE

# %% [markdown]
# Variables & Data Types:
#
# What is a Variable?
# A variable is a named container for storing data.
#
# Data Types in Python
# Data Type	Mutable	Indexed	Example
# String (str)	❌ No	✅ Yes	"Python"
# Integer (int)	❌ No	❌ No	10
# Float (float)	❌ No	❌ No	3.14
# Boolean (bool)	❌ No	❌ No	True
# List (list)	✅ Yes	✅ Yes	[1,2,3]
# Tuple (tuple)	❌ No	✅ Yes	(1,2)
# Dictionary (dict)	✅ Yes	❌ No	{"a":1}
# Set (set)	✅ Yes	❌ No	{1,2}

# %%
def add_numbers(num1 , num2):
        return num1 + num2
        
result = add_numbers(100,1012)

print(f"The sum is: {result}")
# Out:
# The sum is: 1112

# %%
text = "Python Programming "

# Indexing
print(text[0])
print(text[-2])
print(text[5])

# slicing 0-5 
print(text[0:6])
print(text[7:-1])
# Reverse
print(text[::-1])
# Out:
# P
# g
# n
# Python
# Programming
#  gnimmargorP nohtyP

# %%
language="Python"

language[2:5] #(excluded) #slicing
# Out:
# 'tho'

# %% [markdown]
# Common String Operations

# %%
# Concatenation ( + )
first = "Hello"
second = "World"
print( first +" "+ second )

# Repetition ( * )

laugh = "ha"
print(laugh*3)

# Membership(in)

name = "python"
print("py"in"python")
print("java"in"python")
# Out:
# Hello World
# hahaha
# True
# False

# %% [markdown]
# Concatenation(+)

# %%
first_name="Rafi Ahmed"
last_name="Rizvee"

full_name=first_name+" "+last_name
print(full_name)
# Out:
# Rafi Ahmed Rizvee

# %% [markdown]
# Repetition(*)

# %%
language="Haa"

print(language*3)
# Out:
# HaaHaaHaa

# %% [markdown]
# Membership(in)

# %%
name="Rafi Ahmed Rizvee"

print(name)

print("Rizvee" in name)
print("Rafee" in name)
# Out:
# Rafi Ahmed Rizvee
# True
# False

# %%
print("Hello" + " World")   # Concatenation
print("Python " * 3)       # Repetition
print(len("Python"))       # Length
print("Python".upper())    # Uppercase
print("Python".lower())    # lowercase
print("Py" in "Python") # check membership
print("ab" in "Python") # check membership
# Out:
# Hello World
# Python Python Python
# 6
# PYTHON
# python
# True
# False

# %% [markdown]
# Integers (int) and Floats (float)
# Properties
# Immutable
# Used for numeric calculations

# %%
a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)   # Floor division
print(a % b)    # Modulus
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1

# %% [markdown]
# problem -> solution
#
# naive approach -> beginner (subset)
# problem -> optimize
# 4 sec -> 2 sec

# %%
# logic

list=[] # mutable # index (orderd)

tuple=() # immutable #indexed # ordered


d={
   "name" : "Rafi Ahmed Rizvee",
   "age" : 10

}
